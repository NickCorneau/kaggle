# %% [markdown]
# # Reading in the Data

# %%
import csv as csv
import numpy as np
import pandas as pd


df = pd.read_csv('csv/train.csv',header=0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Identifying columns that aren't Float type or with NaN's

# %%
def floatOrNan (df):
    for col in df:
        if (df[col].dtypes != "float64"):
            print col, df[col].dtypes
        if ((len(df[df[col].isnull() == True])) > 0):
            print col, "Contains NaN's"
floatOrNan(df)
# Out:
# PassengerId int64
# Survived int64
# Pclass int64
# Name object
# Sex object
# Age Contains NaN's
# SibSp int64
# Parch int64
# Ticket object
# Cabin object
# Cabin Contains NaN's
# Embarked object
# Embarked Contains NaN's

# %% [markdown]
# # Dealing with NaN's in Age

# %% [markdown]
# I will replace the NaN's in Age with the median age of each passenger based off their respective gender and class.

# %%
median_ages = np.zeros((2,3))
median_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %% [markdown]
# Map passenger's gender to 0 or 1 in order to map gender and class later on.

# %%
df['Sex'] = df['Sex'].map({'female':0, 'male':1}).astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Calculate median age by gender and class.

# %%
for i in range(0,2):
    for j in range(0,3):
        median_ages[i,j] = df[(df['Sex'] == i) & \
                              (df['Pclass'] == j+1)]['Age'].dropna().median()
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %% [markdown]
# Replace NaN's with median age for passenger's gender and class

# %%
for i in range(0,2):
    for j in range(0,3):
        df.loc[(df.Age.isnull()) & (df.Sex == i) & (df.Pclass == j+1), \
                'Age'] = median_ages[i,j]
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Confirm Age column is no longer empty

# %%
# Checks for empty columns in df
for column in df:
    if (len(df[df[column].isnull() == True])) > 0:
        print column
# Out:
# Cabin
# Embarked

# %% [markdown]
# # Converting int64 col's to float

# %%
for col in df:
    if (df[col].dtypes == "int64"):
        df[col] = df[col].astype(float)

# %% [markdown]
# Confirm int's are converted.

# %%
for col in df:
    if (df[col].dtypes != "float64"):
        print col, df[col].dtypes
    if ((len(df[df[col].isnull() == True])) > 0):
        print col, "Contains NaN's"
# Out:
# Name object
# Ticket object
# Cabin object
# Cabin Contains NaN's
# Embarked object
# Embarked Contains NaN's

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  1.0  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  0.0  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  1.0  35.0    0.0    0.0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# # Converting object col's to float

# %% [markdown]
# ### Name

# %%
# Name: Nothing to do with name and can't be converted.
df = df.drop('Name',axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0          1.0       0.0     3.0  1.0  22.0    1.0    0.0         A/5 21171
# 1          2.0       1.0     1.0  0.0  38.0    1.0    0.0          PC 17599
# 2          3.0       1.0     3.0  0.0  26.0    0.0    0.0  STON/O2. 3101282
# 3          4.0       1.0     1.0  0.0  35.0    1.0    0.0            113803
# 4          5.0       0.0     3.0  1.0  35.0    0.0    0.0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %% [markdown]
# ### Embarked

# %%
# Embarked: Only three ports, so map to 0 1 2.
df['Embarked'] = df['Embarked'].map({'S':0, 'C':1, 'Q':2}).astype(float)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0          1.0       0.0     3.0  1.0  22.0    1.0    0.0         A/5 21171
# 1          2.0       1.0     1.0  0.0  38.0    1.0    0.0          PC 17599
# 2          3.0       1.0     3.0  0.0  26.0    0.0    0.0  STON/O2. 3101282
# 3          4.0       1.0     1.0  0.0  35.0    1.0    0.0            113803
# 4          5.0       0.0     3.0  1.0  35.0    0.0    0.0            373450
#
#       Fare Cabin  Embarked
# 0   7.2500   NaN       0.0
# 1  71.2833   C85       1.0
# 2   7.9250   NaN       0.0
# 3  53.1000  C123       0.0
# 4   8.0500   NaN       0.0

# %%
median_embarked = np.zeros((2,3))
median_embarked
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
for i in range(0,2):
    for j in range(0,3):
        median_embarked[i,j] = df[(df['Sex'] == i) & \
                              (df['Pclass'] == j+1)]['Embarked'].dropna().mean()
median_embarked
# Out:
# array([[ 0.48913043,  0.14473684,  0.61805556],
#        [ 0.36065574,  0.11111111,  0.34870317]])

# %%
# Take the average port embarked by passengers based on their class and sex
for i in range(0,2):
    for j in range(0,3):
        median_embarked[i,j] = round(median_embarked[i,j] * 3)
median_embarked
# Out:
# array([[ 1.,  0.,  2.],
#        [ 1.,  0.,  1.]])

# %%
for i in range(0,2):
    for j in range(0,3):
        df.loc[(df.Embarked.isnull()) & (df.Sex == i) & (df.Pclass == j+1), \
                'Embarked'] = median_embarked[i,j]

# %% [markdown]
# Confirm embarked is all float and no more NaN's.

# %%
for col in df:
    if (df[col].dtypes != "float64"):
        print col, df[col].dtypes
    if ((len(df[df[col].isnull() == True])) > 0):
        print col, "Contains NaN's"
# Out:
# Ticket object
# Cabin object
# Cabin Contains NaN's

# %% [markdown]
# ### Ticket

# %%
import re
# Strip all the prefixes
df['Ticket'] = df['Ticket'].map(lambda x: (re.sub(".*? (.+)", "\\1", x)))

# Define function that returns 0 if it can't convert to type
def tryconvert(value, default, *types):
    for t in types:
        try:
            return t(value)
        except ValueError, TypeError:
            continue
    return default

df['Ticket'] = df['Ticket'].map(lambda x: tryconvert(x,0,float))

# %% [markdown]
# Confirm Ticket is a float.

# %%
for col in df:
    if (df[col].dtypes != "float64"):
        print col, df[col].dtypes
    if ((len(df[df[col].isnull() == True])) > 0):
        print col, "Contains NaN's"
# Out:
# Cabin object
# Cabin Contains NaN's

# %% [markdown]
# ### Cabin

# %%
# Drop cabin because not much can be done with it right now.
df = df.drop('Cabin', axis=1)

# %% [markdown]
# Confirm everything is a float

# %%
for col in df:
    if (df[col].dtypes != "float64"):
        print col, df[col].dtypes
    if ((len(df[df[col].isnull() == True])) > 0):
        print col, "Contains NaN's"

# %% [markdown]
# # Random Forests! Finally!

# %%
#df = df.drop('Ticket',axis=1)
df = df.drop('PassengerId', axis=1)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Ticket      Fare  Embarked
# 0         0.0     3.0  1.0  22.0    1.0    0.0    21171.0    7.2500       0.0
# 1         1.0     1.0  0.0  38.0    1.0    0.0    17599.0   71.2833       1.0
# 2         1.0     3.0  0.0  26.0    0.0    0.0  3101282.0    7.9250       0.0
# 3         1.0     1.0  0.0  35.0    1.0    0.0   113803.0   53.1000       0.0
# 4         0.0     3.0  1.0  35.0    0.0    0.0   373450.0    8.0500       0.0
# 5         0.0     3.0  1.0  25.0    0.0    0.0   330877.0    8.4583       2.0
# 6         0.0     1.0  1.0  54.0    0.0    0.0    17463.0   51.8625       0.0
# 7         0.0     3.0  1.0   2.0    3.0    1.0   349909.0   21.0750       0.0
# 8         1.0     3.0  0.0  27.0    0.0    2.0   347742.0   11.1333       0.0
# 9         1.0     2.0  0.0  14.0    1.0    0.0   237736.0   30.0708       1.0
# 10        1.0     3.0  0.0   4.0    1.0    1.0     9549.0   16.7000       0.0
# 11        1.0     1.0  0.0  58.0    0.0    0.0   113783.0   26.5500       0.0
# 12        0.0     3.0  1.0  20.0    0.0    0.0     2151.0    8.0500       0.0
# 13        0.0     3.0  1.0  39.0    1.0    5.0   347082.0   31.2750       0.0
# 14        0.0     3.0  0.0  14.0    0.0    0.0   350406.0    7.8542       0.0
# 15        1.0     2.0  0.0  55.0    0.0    0.0   248706.0   16.0000       0.0
# 16        0.0     3.0  1.0   2.0    4.0    1.0   382652.0   29.1250       2.0
# 17        1.0     2.0  1.0  30.0    0.0    0.0   244373.0   13.0000       0.0
# 18        0.0     3.0  0.0  31.0    1.0    0.0   345763.0   18.0000       0.0
# 19        1.0     3.0  0.0  21.5    0.0    0.0     2649.0    7.2250       1.0
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 416    male   NaN      0      0              359309    8.0500
# 417    male   NaN      1      1                2668   22.3583
#
#                Cabin Embarked
# 0                NaN        Q
# 1                NaN        S
# 2                NaN        Q
# 3                NaN        S
# 4                NaN        S
# 5                NaN        S
# 6                NaN        Q
# 7                NaN        S
# 8                NaN        C
# 9                NaN        S
# 10               NaN        S
# 11               NaN        S
# 12               B45        S
# 13               NaN        S
# 14               E31        S
# 15               NaN        C
# 16               NaN        Q
# 17               NaN        C
# 18               NaN        S
# 19               NaN        C
# 20               NaN        C
# 21               NaN        S
# 22               NaN        S
# 23               NaN        C
# 24   B57 B59 B63 B66        C
# 25               NaN        S
# 26               B36        C
# 27               NaN        C
# 28               A21        S
# 29               NaN        C
# ..               ...      ...
# 388              NaN        Q
# 389              NaN        S
# 390              B24        S
# 391              D28        S
# 392              NaN        S
# 393              NaN        S
# 394              NaN        S
# 395              C31        S
# 396              NaN        Q
# 397              B41        C
# 398              NaN        S
# 399              NaN        Q
# 400               C7        S
# 401              NaN        S
# 402              NaN        C
# 403              NaN        S
# 404              D40        C
# 405              D38        C
# 406              NaN        S
# 407              C80        C
# 408              NaN        Q
# 409              NaN        S
# 410              NaN        Q
# 411              C78        Q
# 412              NaN        S
# 413              NaN        S
# 414             C105        C
# 415              NaN        S
# 416              NaN        S
# 417              NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# Which ones need cleaning?

# %%
floatOrNan(test_df)
# Out:
# PassengerId int64
# Pclass int64
# Name object
# Sex object
# Age Contains NaN's
# SibSp int64
# Parch int64
# Ticket object
# Fare Contains NaN's
# Cabin object
# Cabin Contains NaN's
# Embarked object

# %% [markdown]
# ## Drop unneeded columns

# %%
test_df = test_df.drop('PassengerId', axis=1)
test_df = test_df.drop('Name', axis=1)
test_df = test_df.drop('Cabin', axis=1)
#test_df = test_df.drop('Ticket', axis=1)

# %%
floatOrNan(test_df)
# Out:
# Pclass int64
# Sex object
# Age Contains NaN's
# SibSp int64
# Parch int64
# Ticket object
# Fare Contains NaN's
# Embarked object

# %% [markdown]
# ### Convert int's to floats

# %%
for col in test_df:
    if (test_df[col].dtypes == "int64"):
        test_df[col] = test_df[col].astype(float)

# %%
test_df
# Out:
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 0       3.0    male  34.5    0.0    0.0              330911    7.8292        Q
# 1       3.0  female  47.0    1.0    0.0              363272    7.0000        S
# 2       2.0    male  62.0    0.0    0.0              240276    9.6875        Q
# 3       3.0    male  27.0    0.0    0.0              315154    8.6625        S
# 4       3.0  female  22.0    1.0    1.0             3101298   12.2875        S
# 5       3.0    male  14.0    0.0    0.0                7538    9.2250        S
# 6       3.0  female  30.0    0.0    0.0              330972    7.6292        Q
# 7       2.0    male  26.0    1.0    1.0              248738   29.0000        S
# 8       3.0  female  18.0    0.0    0.0                2657    7.2292        C
# 390     1.0  1.0  23.0    0.0    0.0               12749   93.5000       0.0
# 391     1.0  0.0  51.0    0.0    1.0            PC 17592   39.4000       0.0
# 392     3.0  1.0  13.0    0.0    2.0           C.A. 2673   20.2500       0.0
# 393     2.0  1.0  47.0    0.0    0.0          C.A. 30769   10.5000       0.0
# 394     3.0  1.0  29.0    3.0    1.0              315153   22.0250       0.0
# 395     1.0  0.0  18.0    1.0    0.0               13695   60.0000       0.0
# 396     3.0  1.0  24.0    0.0    0.0              371109    7.2500       2.0
# 397     1.0  0.0  48.0    1.0    1.0               13567   79.2000       1.0
# 398     3.0  1.0  22.0    0.0    0.0              347065    7.7750       0.0
# 399     3.0  1.0  31.0    0.0    0.0               21332    7.7333       2.0
# 400     1.0  0.0  30.0    0.0    0.0               36928  164.8667       0.0
# 401     2.0  1.0  38.0    1.0    0.0               28664   21.0000       0.0
# 402     1.0  0.0  22.0    0.0    1.0              112378   59.4000       1.0
# 403     1.0  1.0  17.0    0.0    0.0              113059   47.1000       0.0
# 404     1.0  1.0  43.0    1.0    0.0               17765   27.7208       1.0
# 405     2.0  1.0  20.0    0.0    0.0       SC/PARIS 2166   13.8625       1.0
# 406     2.0  1.0  23.0    1.0    0.0               28666   10.5000       0.0
# 407     1.0  1.0  50.0    1.0    1.0              113503  211.5000       1.0
# 408     3.0  0.0   NaN    0.0    0.0              334915    7.7208       2.0
# 409     3.0  0.0   3.0    1.0    1.0  SOTON/O.Q. 3101315   13.7750       0.0
# 410     3.0  0.0   NaN    0.0    0.0              365237    7.7500       2.0
# 411     1.0  0.0  37.0    1.0    0.0               19928   90.0000       2.0
# 412     3.0  0.0  28.0    0.0    0.0              347086    7.7750       0.0
# 413     3.0  1.0   NaN    0.0    0.0           A.5. 3236    8.0500       0.0
# 414     1.0  0.0  39.0    0.0    0.0            PC 17758  108.9000       1.0
# 415     3.0  1.0  38.5    0.0    0.0  SOTON/O.Q. 3101262    7.2500       0.0
# 416     3.0  1.0   NaN    0.0    0.0              359309    8.0500       0.0
# 417     3.0  1.0   NaN    1.0    1.0                2668   22.3583       1.0
#
# [418 rows x 8 columns]

# %%
import re
# Strip all the prefixes
test_df['Ticket'] = test_df['Ticket'].map(lambda x: (re.sub(".*? (.+)", "\\1", x)))

# Define function that returns 0 if it can't convert to type
def tryconvert(value, default, *types):
    for t in types:
        try:
            return t(value)
        except ValueError, TypeError:
            continue
    return default

test_df['Ticket'] = test_df['Ticket'].map(lambda x: tryconvert(x,0,float))

# %%
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Ticket      Fare  Embarked
# 0       3.0  1.0  34.5    0.0    0.0   330911.0    7.8292       2.0
# 1       3.0  0.0  47.0    1.0    0.0   363272.0    7.0000       0.0
# 2       2.0  1.0  62.0    0.0    0.0   240276.0    9.6875       2.0
# 3       3.0  1.0  27.0    0.0    0.0   315154.0    8.6625       0.0
# 4       3.0  0.0  22.0    1.0    1.0  3101298.0   12.2875       0.0
# 5       3.0  1.0  14.0    0.0    0.0     7538.0    9.2250       0.0
# 405     2.0  1.0  20.0    0.0    0.0     2166.0   13.8625       1.0
# 406     2.0  1.0  23.0    1.0    0.0    28666.0   10.5000       0.0
# 407     1.0  1.0  50.0    1.0    1.0   113503.0  211.5000       1.0
# 408     3.0  0.0   NaN    0.0    0.0   334915.0    7.7208       2.0
# 409     3.0  0.0   3.0    1.0    1.0  3101315.0   13.7750       0.0
# 410     3.0  0.0   NaN    0.0    0.0   365237.0    7.7500       2.0
# 411     1.0  0.0  37.0    1.0    0.0    19928.0   90.0000       2.0
# 412     3.0  0.0  28.0    0.0    0.0   347086.0    7.7750       0.0
# 413     3.0  1.0   NaN    0.0    0.0     3236.0    8.0500       0.0
# 414     1.0  0.0  39.0    0.0    0.0    17758.0  108.9000       1.0
# 415     3.0  1.0  38.5    0.0    0.0  3101262.0    7.2500       0.0
# 416     3.0  1.0   NaN    0.0    0.0   359309.0    8.0500       0.0
# 417     3.0  1.0   NaN    1.0    1.0     2668.0   22.3583       1.0
#
# [418 rows x 8 columns]

# %%
for i in range(0,2):
    for j in range(0,3):
        median_ages[i,j] = test_df[(test_df['Sex'] == i) & \
                              (test_df['Pclass'] == j+1)]['Age'].dropna().median()
median_ages
# Out:
# array([[ 41.,  24.,  22.],
#        [ 42.,  28.,  24.]])

# %%
for i in range(0,2):
    for j in range(0,3):
        test_df.loc[(test_df.Age.isnull()) & (test_df.Sex == i) & (test_df.Pclass == j+1), \
                'Age'] = median_ages[i,j]

# %%
test_df
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Ticket      Fare  Embarked
# 0       3.0  1.0  34.5    0.0    0.0   330911.0    7.8292       2.0
# 1       3.0  0.0  47.0    1.0    0.0   363272.0    7.0000       0.0
# 2       2.0  1.0  62.0    0.0    0.0   240276.0    9.6875       2.0
# 3       3.0  1.0  27.0    0.0    0.0   315154.0    8.6625       0.0
# 4       3.0  0.0  22.0    1.0    1.0  3101298.0   12.2875       0.0
# 5       3.0  1.0  14.0    0.0    0.0     7538.0    9.2250       0.0
# 6       3.0  0.0  30.0    0.0    0.0   330972.0    7.6292       2.0
# 7       2.0  1.0  26.0    1.0    1.0   248738.0   29.0000       0.0
# 8       3.0  0.0  18.0    0.0    0.0     2657.0    7.2292       1.0
# 9       3.0  1.0  21.0    2.0    0.0    48871.0   24.1500       0.0
# 10      3.0  1.0  24.0    0.0    0.0   349220.0    7.8958       0.0
# 11      1.0  1.0  46.0    0.0    0.0      694.0   26.0000       0.0
# 12      1.0  0.0  23.0    1.0    0.0    21228.0   82.2667       0.0
# 13      2.0  1.0  63.0    1.0    0.0    24065.0   26.0000       0.0
# 14      1.0  0.0  47.0    1.0    0.0     5734.0   61.1750       0.0
# 15      2.0  0.0  24.0    1.0    0.0     2167.0   27.7208       1.0
# 16      2.0  1.0  35.0    0.0    0.0   233734.0   12.3500       2.0
# 17      3.0  1.0  21.0    0.0    0.0     2692.0    7.2250       1.0
# 18      3.0  0.0  27.0    1.0    0.0  3101270.0    7.9250       0.0
# 19      3.0  0.0  45.0    0.0    0.0     2696.0    7.2250       1.0
